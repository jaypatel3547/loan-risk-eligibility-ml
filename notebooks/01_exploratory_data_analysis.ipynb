# %% [markdown]
# Goal 1: Predict the loan approval status (classification)

# %% [markdown]
# Goal 2: Predict maximum loan amount for applicants whose loan status is approved (regression)

# %%
import pandas as pd

# %%
#loading the dataset
df = pd.read_csv('/content/loan_applications_data.csv')
# Out:
# /tmp/ipykernel_287/1770596827.py:2: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/loan_applications_data.csv')

# %%
#displaying the first few instances of the data
df.head()
# Out:
#        id  applicant_account_No.  bank_sort_code   age sex  \
# 0  717474               62012825           90025  21.0   M
# 1  211588                3829308          239285  21.0   M
# 2  597607               79622422          300083  23.0   M
# 3  684154               86043250          405179  40.0   M
# 4  343369               73510088          300066  40.0   M
#
#   education_qualifications    income home_ownership  employment_length  \
# 0                 Unknown    12000.0            OWN                0.0
# 1                 Unknown    13200.0            OWN                2.0
# 2                 Unknown     9600.0           RENT                5.0
# 3                 Unknown   182004.0           RENT                3.0
# 4                 Unknown    90000.0       MORTGAGE                3.0
#
#        loan_intent  loan_amount  loan_interest_rate  loan_income_ratio  \
# 0        EDUCATION        15000                6.99               0.12
# ...

# %%
#displaying the dimensions of the data
df.shape
# Out:
# (58645, 18)

# %%
#displaying the list of columns
list(df.columns)
# Out:
# ['id',
#  'applicant_account_No.',
#  'bank_sort_code',
#  'age',
#  'sex',
#  'education_qualifications',
#  'income',
#  'home_ownership',
#  'employment_length',
#  'loan_intent',
#  'loan_amount',
#  'loan_interest_rate',
#  'loan_income_ratio',
#  'payment_default_on_file',
#  'credit_history_length',
#  'loan_approval_status',
#  'max_loan_amount(allowed)',
#  'credit_application_acceptance']

# %%
#displaying the type of variable data types
#checking categorical and numerical variables
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58645 entries, 0 to 58644
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   id                             58645 non-null  int64
#  1   applicant_account_No.          58645 non-null  int64
#  2   bank_sort_code                 58645 non-null  int64
#  3   age                            58639 non-null  float64
#  4   sex                            362 non-null    object
#  5   education_qualifications       58645 non-null  object
#  6   income                         58614 non-null  float64
#  7   home_ownership                 58645 non-null  object
#  8   employment_length              58630 non-null  float64
#  9   loan_intent                    58645 non-null  object
#  10  loan_amount                    58645 non-null  int64
#  11  loan_interest_rate             58635 non-null  float64
# ...

# %%
#basic descriptive statistics
df.describe().transpose()
# Out:
#                                  count          mean           std  \
# id                             58645.0  5.494166e+05  2.600044e+05
# applicant_account_No.          58645.0  5.055471e+07  2.864283e+07
# bank_sort_code                 58645.0  3.537375e+05  2.275277e+05
# age                            58639.0  2.755504e+01  6.099005e+00
# income                         58614.0  6.405295e+04  3.793834e+04
# employment_length              58630.0  4.702746e+00  3.999875e+00
# loan_amount                    58645.0  9.217557e+03  5.563807e+03
# loan_interest_rate             58635.0  1.068922e+01  3.257150e+00
# loan_income_ratio              58645.0  1.592375e-01  9.169179e-02
# credit_history_length          58645.0  5.813062e+00  4.027495e+00
# max_loan_amount(allowed)       58645.0  2.823538e+05  5.148478e+07
# credit_application_acceptance  58644.0  1.423846e-01  3.494471e-01
#
#                                       min          25%          50%  \
# ...

# %%
df.describe(include='all').transpose()
# Out:
#                                  count unique        top   freq  \
# id                             58645.0    NaN        NaN    NaN
# applicant_account_No.          58645.0    NaN        NaN    NaN
# bank_sort_code                 58645.0    NaN        NaN    NaN
# age                            58639.0    NaN        NaN    NaN
# sex                                362      4          M    126
# education_qualifications         58645      6    Unknown  58303
# income                         58614.0    NaN        NaN    NaN
# home_ownership                   58645      4       RENT  30594
# employment_length              58630.0    NaN        NaN    NaN
# loan_intent                      58645      6  EDUCATION  12271
# loan_amount                    58645.0    NaN        NaN    NaN
# loan_interest_rate             58635.0    NaN        NaN    NaN
# loan_income_ratio              58645.0    NaN        NaN    NaN
# payment_default_on_file          58640      4          N  49933
# ...

# %%
#missing data values
df.isnull().sum()
# Out:
# id                                   0
# applicant_account_No.                0
# bank_sort_code                       0
# age                                  6
# sex                              58283
# education_qualifications             0
# income                              31
# home_ownership                       0
# employment_length                   15
# loan_intent                          0
# loan_amount                          0
# loan_interest_rate                  10
# loan_income_ratio                    0
# payment_default_on_file              5
# credit_history_length                0
# loan_approval_status                 1
# max_loan_amount(allowed)             0
# credit_application_acceptance        1
# dtype: int64

# %%
#displaying portion of missing data
df.isnull().sum()/len(df) * 100
# Out:
# id                                0.000000
# applicant_account_No.             0.000000
# bank_sort_code                    0.000000
# age                               0.010231
# sex                              99.382727
# education_qualifications          0.000000
# income                            0.052860
# home_ownership                    0.000000
# employment_length                 0.025578
# loan_intent                       0.000000
# loan_amount                       0.000000
# loan_interest_rate                0.017052
# loan_income_ratio                 0.000000
# payment_default_on_file           0.008526
# credit_history_length             0.000000
# loan_approval_status              0.001705
# max_loan_amount(allowed)          0.000000
# credit_application_acceptance     0.001705
# dtype: float64
